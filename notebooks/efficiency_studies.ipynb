# %% [markdown]
# # Efficiency Studies
#
# Use RapidSim-generated samples of $D^0\to K^0_S\pi^+\pi^-$ and $D^0\to\pi^+\pi^-$ to determine the possibility of correcting the trigger efficiency of the former with the latter:
#
# $$
# \begin{align}
# A_{\text{raw}}(D^{*+}\to D^0(\to K^0_S\pi^+\pi^-)\pi_s^+) &= A_{\text{HLT1}}(D^0\to K^0_S\pi^+\pi^-) + A_{\text{det}}(K^0_S) + A_{\text{det}}(\pi^+\pi^-) \nonumber \\
# &+ A_{\text{prod}}(D^{*+}) + A_{\text{det}}(\pi_s^+) \nonumber\\
# &+ A_{\text{CP}}^{\text{dir}}(D^0\to K^0_S\pi^+\pi^-) \\
# A_{\text{raw}}(D^{*+}\to D^0(\to\pi^+\pi^-)\pi_s^+) &= A_{\text{HLT1}}(D^0\to\pi^+\pi^-) + A_{\text{det}}(\pi^+\pi^-) \nonumber\\
# &+ A_{\text{prod}}(D^{*+}) + A_{\text{det}}(\pi_s^+) \nonumber\\
# &+ A_{\text{CP}}^{\text{dir}}(D^0\to\pi^+\pi^-)
# \end{align}
# $$
#
# We can assume $A_{\text{CP}}^{\text{dir}}(D^0\to K^0_S\pi^+\pi^-)\approx 0$, while $A_{\text{CP}}^{\text{dir}}(D^0\to\pi^+\pi^-) = (2.30 \pm 0.56) \times 10^{-3}$.
#
# The HLT1 asymmetry, aside the $D^0$ mass window, can be factorised as
# $$
# \begin{align}
# A_{\text{HLT1}}(D^0\to K^0_S\pi^+\pi^-) &\approx A_{\text{HLT1}}(K^0_S) + A_{\text{HLT1}}(\pi^+\pi^-) \\
# A_{\text{HLT1}}(D^0\to \pi^+\pi^-) &\approx A_{\text{HLT1}}(\pi^+\pi^-)
# \end{align}
# $$
# in the region where the asymmetries are up to a few percents.
#
# And the raw asymmetries become
# $$
# \begin{align}
# A_{\text{raw}}(D^{*+}\to D^0(\to K^0_S\pi^+\pi^-)\pi_s^+) &= A_{\text{HLT1}}(K^0_S) + A_{\text{HLT1}}(\pi^+\pi^-) + A_{\text{det}}(K^0_S) + A_{\text{det}}(\pi^+\pi^-) \nonumber\\
# &+ A_{\text{prod}}(D^{*+}) + A_{\text{det}}(\pi_s^+) \\
# A_{\text{raw}}(D^{*+}\to D^0(\to\pi^+\pi^-)\pi_s^+) &= A_{\text{HLT1}}(\pi^+\pi^-) + A_{\text{det}}(\pi^+\pi^-) \nonumber\\
# &+ A_{\text{prod}}(D^{*+}) + A_{\text{det}}(\pi_s^+)
# \end{align}
# $$
#
# Implying that
# $$
# \begin{align}
# A_{\text{raw}}(D^{*+}\to D^0(\to K^0_S\pi^+\pi^-)\pi_s^+) &= A_{\text{raw}}(D^{*+}\to D^0(\to\pi^+\pi^-)\pi_s^+) + A_{\text{HLT1}}(K^0_S) + A_{\text{det}}(K^0_S)
# \end{align}
# $$
# when the kinematic distributions of the $D^{*+}$, $\pi^+_s$, $\pi^+$, and $\pi^-$ are equalised.

# %% [markdown]
# ## RapidSim Simulations
#
# Let's start by looking at the RapidSim simulations

# %%
import uproot

# %%
# Load the data from the ROOT files
d2pipi = uproot.open("../data/DstD02pipi_tree.root")
d2kspipi = uproot.open("../data/DstD02KSpipi_res_tree.root")

# %%
d2pipi['DecayTree'].keys()
# Out:
# ['nEvent',
#  'Dst_M',
#  'Dst_M_TRUE',
#  'D0_M',
#  'D0_M_TRUE',
#  'Dst_E',
#  'Dst_E_TRUE',
#  'D0_E',
#  'D0_E_TRUE',
#  'Dst_P',
#  'Dst_P_TRUE',
#  'D0_P',
#  'D0_P_TRUE',
#  'Dst_PT',
#  'Dst_PT_TRUE',
#  'D0_PT',
#  'D0_PT_TRUE',
#  'Dst_PX',
#  'Dst_PX_TRUE',
#  'D0_PX',
#  'D0_PX_TRUE',
#  'Dst_PY',
#  'Dst_PY_TRUE',
#  'D0_PY',
#  'D0_PY_TRUE',
#  'Dst_PZ',
#  'Dst_PZ_TRUE',
#  'D0_PZ',
#  'D0_PZ_TRUE',
#  'Dst_y',
#  'Dst_y_TRUE',
#  'D0_y',
#  'D0_y_TRUE',
#  'Dst_eta',
#  'Dst_eta_TRUE',
#  'D0_eta',
#  'D0_eta_TRUE',
#  'Dst_IP',
#  'Dst_IP_TRUE',
#  'D0_IP',
#  'D0_IP_TRUE',
#  'Dst_SIGMAIP_TRUE',
#  'D0_SIGMAIP_TRUE',
#  'Dst_FD',
#  'Dst_FD_TRUE',
#  'D0_FD',
#  'D0_FD_TRUE',
#  'Dst_vtxX',
#  'Dst_vtxX_TRUE',
#  'D0_vtxX',
#  'D0_vtxX_TRUE',
#  'Dst_vtxY',
#  'Dst_vtxY_TRUE',
#  'D0_vtxY',
#  'D0_vtxY_TRUE',
#  'Dst_vtxZ',
#  'Dst_vtxZ_TRUE',
#  'D0_vtxZ',
#  'D0_vtxZ_TRUE',
#  'Dst_origX',
#  'Dst_origX_TRUE',
#  'D0_origX',
#  'D0_origX_TRUE',
#  'Dst_origY',
#  'Dst_origY_TRUE',
#  'D0_origY',
#  'D0_origY_TRUE',
#  'Dst_origZ',
#  'Dst_origZ_TRUE',
#  'D0_origZ',
#  'D0_origZ_TRUE',
#  'Dst_gamma',
#  'Dst_gamma_TRUE',
#  'D0_gamma',
#  'D0_gamma_TRUE',
#  'Dst_beta',
#  'Dst_beta_TRUE',
#  'D0_beta',
#  'D0_beta_TRUE',
#  'pis_P',
#  'pis_P_TRUE',
#  'pim_P',
#  'pim_P_TRUE',
#  'pip_P',
#  'pip_P_TRUE',
#  'pis_PT',
#  'pis_PT_TRUE',
#  'pim_PT',
#  'pim_PT_TRUE',
#  'pip_PT',
#  'pip_PT_TRUE',
#  'pis_PX',
#  'pis_PX_TRUE',
#  'pim_PX',
#  'pim_PX_TRUE',
#  'pip_PX',
#  'pip_PX_TRUE',
#  'pis_PY',
#  'pis_PY_TRUE',
#  'pim_PY',
#  'pim_PY_TRUE',
#  'pip_PY',
#  'pip_PY_TRUE',
#  'pis_PZ',
#  'pis_PZ_TRUE',
#  'pim_PZ',
#  'pim_PZ_TRUE',
#  'pip_PZ',
#  'pip_PZ_TRUE',
#  'pis_IP',
#  'pis_IP_TRUE',
#  'pim_IP',
#  'pim_IP_TRUE',
#  'pip_IP',
#  'pip_IP_TRUE',
#  'pis_SIGMAIP_TRUE',
#  'pim_SIGMAIP_TRUE',
#  'pip_SIGMAIP_TRUE',
#  'pis_eta',
#  'pis_eta_TRUE',
#  'pim_eta',
#  'pim_eta_TRUE',
#  'pip_eta',
#  'pip_eta_TRUE',
#  'pis_y',
#  'pis_y_TRUE',
#  'pim_y',
#  'pim_y_TRUE',
#  'pip_y',
#  'pip_y_TRUE',
#  'pis_ProbNNpi',
#  'pim_ProbNNpi',
#  'pip_ProbNNpi',
#  'pis_ProbNNk',
#  'pim_ProbNNk',
#  'pip_ProbNNk',
#  'pis_ProbNNmu',
#  'pim_ProbNNmu',
#  'pip_ProbNNmu']

# %% [markdown]
# Let's plot a few kinematic distributions to check the differences between the two samples.
#
# - D* PT
# - D* P
# - D* ETA
# - D* PHI

# %%
from analysis_helpers.plotting import plot_hists
import matplotlib.pyplot as plt

# %%
vars_to_plot = {
    'Dst_PT': {'name': r'$p_T(D^*)$', 'unit': 'GeV/c', 'range': (0, 20)}, 
    'Dst_P': {'name': r'$p(D^*)$', 'unit': 'GeV/c', 'range': (0, 500)}, 
    'Dst_eta': {'name': r'$\eta(D^*)$', 'unit': '', 'log': True, 'range': (1.5, 6)},
    'pip_IP': {'name': r'$IP(\pi^+)$', 'unit': 'mm', 'log': True, 'range': (0, 1)},
    'pim_IP': {'name': r'$IP(\pi^-)$', 'unit': 'mm', 'log': True, 'range': (0, 1)},
    'pip_IP': {'name': r'$IP(\pi^+)$', 'unit': 'mm', 'log': True, 'range': (0, 0.1)},
    'pim_IP': {'name': r'$IP(\pi^-)$', 'unit': 'mm', 'log': True, 'range': (0, 0.1)}
    }
for var, props in vars_to_plot.items():
    d2pipi_values = d2pipi['DecayTree'][var].array(library="np")
    d2kspipi_values = d2kspipi['DecayTree'][var].array(library="np")
    fig, ax = plot_hists([d2pipi_values, d2kspipi_values], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$'], name=props['name'], unit=props.get('unit', ''), density=True, bins=50, range=props.get('range', None), log=props.get('log', False))
    ax.legend()

# %% [markdown]
# ## Create a Dataframe to apply the selection
#
# To determine whether a candidate is selected, we use dataframes with variables calculated out of the RapidSim output.

# %%
# ['hh_PT', 'hh_VERTEX_CHI2', 'hh_ETA', 'hh_DOCA', 'h1_PT', 'h2_PT', 'h1_IP', 'h2_IP', 'hh_CTAU', 'hh_MASS', 'hh_Z', 'PV_Z']
vars_to_use  = [f'{x}_P{y}' for x in ['pip', 'pim'] for y in ['X', 'Y', 'Z']]
vars_to_use += [f'{x}_IP' for x in ['pip', 'pim']]
vars_to_use += ['D0_vtxX', 'D0_vtxY', 'D0_vtxZ', 'Dst_vtxX', 'Dst_vtxY', 'Dst_vtxZ', 'D0_eta', 'D0_M']
df = d2pipi['DecayTree'].arrays(vars_to_use, library="pd")
df.head()
# Out:
#      pip_PX    pip_PY      pip_PZ    pim_PX    pim_PY     pim_PZ    pip_IP  \
# 0  1.021211  0.708308    5.734252  1.153136 -0.616333  15.875556  0.199630
# 1  1.284325  1.013888   14.217216  0.303041 -0.501138  15.397056  0.131511
# 2 -0.381088 -0.971504    8.911476  0.265746  0.755089   6.316130  0.022341
# 3 -0.661370  1.867210   62.546639 -0.335374 -0.172616   3.396060  0.026357
# 4  0.274873 -2.829391  199.147764 -1.035661 -0.893244  79.836141  0.067527
#
#      pim_IP   D0_vtxX   D0_vtxY    D0_vtxZ  Dst_vtxX  Dst_vtxY  Dst_vtxZ  \
# 0  0.092343  0.158141 -0.005243   1.291118 -0.026956  0.006091  0.010144
# 1  0.119185  0.109147  0.023717   2.051125 -0.005839 -0.015075 -0.005006
# 2  0.065941 -0.043217  0.000437   0.208034  0.000068 -0.014880  0.010212
# 3  0.449377 -0.036249  0.111843   3.515442  0.007316  0.001370  0.074520
# 4  0.233339 -0.067692 -0.270373  21.808443 -0.015984 -0.025514 -0.064869
#
#      D0_eta      D0_M
# 0  2.991199  1.864096
# 1  3.570495  1.877391
# 2  4.821866  1.850893
# 3  4.206156  1.850462
# 4  4.989457  1.874944

# %%
from analysis_helpers.kinematics import pseudorapidity, doca, slope, ctau, mass
import numpy as np
df['hh_PT'] = 1000.*( (df['pip_PX']+df['pim_PX'])**2 + (df['pip_PY']+df['pim_PY'])**2)**0.5
df['hh_VERTEX_CHI2'] = np.zeros(len(df))  # Placeholder, need to compute from vertex fit
df['hh_ETA'] = pseudorapidity( df['pip_PX']+df['pim_PX'], df['pip_PY']+df['pim_PY'], df['pip_PZ']+df['pim_PZ'] )
df['hh_DOCA'] = doca( df['D0_vtxX'], df['D0_vtxY'], df['D0_vtxZ'], slope(df['pip_PX'], df['pip_PZ']), slope(df['pip_PY'], df['pip_PZ']), 
                      df['D0_vtxX'], df['D0_vtxY'], df['D0_vtxZ'], slope(df['pim_PX'], df['pim_PZ']), slope(df['pim_PY'], df['pim_PZ']) )
df['h1_PT'] = 1000.*(df['pip_PX']**2 + df['pip_PY']**2)**0.5
df['h2_PT'] = 1000.*(df['pim_PX']**2 + df['pim_PY']**2)**0.5
df['h1_IP'] = df['pip_IP']
df['h2_IP'] = df['pim_IP']
df['D0_DL'] = np.sqrt( (df['D0_vtxX'] - df['Dst_vtxX'])**2 + (df['D0_vtxY'] - df['Dst_vtxY'])**2 + (df['D0_vtxZ'] - df['Dst_vtxZ'])**2 )
df['hh_CTAU'] = ctau( df['D0_DL'], 1864.83, df['hh_PT'] )
df['pip_E'] = np.sqrt(df['pip_PX']**2 + df['pip_PY']**2 + df['pip_PZ']**2 + 0.13957**2)
df['pim_E'] = np.sqrt(df['pim_PX']**2 + df['pim_PY']**2 + df['pim_PZ']**2 + 0.13957**2)
df['hh_MASS'] = 1000.*mass( df['pip_PX'] + df['pim_PX'], df['pip_PY'] + df['pim_PY'], df['pip_PZ'] + df['pim_PZ'], df['pip_E'] + df['pim_E'] )
df['hh_Z'] = df['D0_vtxZ']
df['PV_Z'] = df['Dst_vtxZ']  # Assuming PV is at

# %%
from analysis_helpers.plotting import plot_hist
fig, ax = plot_hist(df['hh_CTAU']/0.4101, name=r'$\tau/\tau_{PDG}$', density=True, bins=50, range=(0, 5), log=True)

# %%
from d02kspipi_asymmetry.selections import hlt1_d2pipi
df['hlt1_d2pipi'] = hlt1_d2pipi(df)
df_hlt1d2pipi = df[df['hlt1_d2pipi']]

# %%
df['hlt1_d2pipi'].value_counts()
# Out:
# hlt1_d2pipi
# False    3720665
# True      508606
# Name: count, dtype: int64

# %%
from analysis_helpers.plotting import plot_removed
fig, ax = plot_removed(df['hh_CTAU'].to_numpy()/0.4101, df['hlt1_d2pipi'].to_numpy(), name=r'$\tau/\tau_{PDG}$', bins=50, range=(0, 5), log=True)

# %% [markdown]
# Do the same for the $D^0\to K^0_S\pi^+\pi^-$ sample.

# %%
# ['KS_hh_DOCA', 'KS_VERTEX_CHI2', 'hh_VERTEX_CHI2', 'KS_hh_CTAU', 'KS_hh_PT', 'KS_hh_MASS', 'KS_PT', 'KS_ETA', 'KS_Z', 'hh_Z', 'KS_MASS', 'KS_PT', 'KS_h1_PT', 'KS_h2_PT', 'KS_h1_P', 'KS_h2_P', 'KS_h1_IP', 'KS_h2_IP', 'hh_PT', 'hh_ETA', 'hh_DOCA', 'h1_PT', 'h2_PT', 'h1_P', 'h2_P', 'h1_IP', 'h2_IP', 'hh_Z']
vars_to_use  = [f'{x}_P{y}' for x in ['pip', 'pim', 'KS_pip', 'KS_pim'] for y in ['X', 'Y', 'Z']]
vars_to_use += [f'{x}_IP' for x in ['pip', 'pim', 'KS_pip', 'KS_pim']]
vars_to_use += [f'{x}_vtx{y}' for x in ['D0', 'Dst', 'KS'] for y in ['X', 'Y', 'Z']]
vars_to_use += ['D0_eta', 'D0_M']
df = d2kspipi['DecayTree'].arrays(vars_to_use, library="pd")
df.head()
# Out:
#      pip_PX    pip_PY     pip_PZ    pim_PX    pim_PY    pim_PZ  KS_pip_PX  \
# 0  0.196684 -0.093180   1.610006 -0.330924  0.519533  2.984750   0.294667
# 1  0.130709 -0.070088  13.424673  0.697092  0.238102  4.142549   0.307362
# 2  0.226786 -0.757654  16.520967 -0.171747 -0.030003  1.755197  -0.174060
# 3 -1.830340 -1.451843  52.727352 -0.460963 -0.662199  8.971918  -2.055184
# 4  0.688412 -0.761533   9.380460  0.143167 -0.205072  1.059953  -0.234972
#
#    KS_pip_PY  KS_pip_PZ  KS_pim_PX  ...   D0_vtxY   D0_vtxZ  Dst_vtxX  \
# 0  -0.198094   3.904649   0.631324  ...  0.052867  1.300509  0.000737
# 1   0.085129   4.734575   0.051773  ...  0.020514  1.472632 -0.022207
# 2   0.463921   7.889631  -0.264965  ... -0.008569  2.501940  0.003130
# 3  -1.644900  50.530579  -0.927132  ... -0.303437  9.220216  0.006852
# 4   0.066284   4.437205  -0.297697  ... -0.433956  7.308402  0.026725
#
#    Dst_vtxY  Dst_vtxZ     KS_vtxX     KS_vtxY      KS_vtxZ    D0_eta      D0_M
# 0  0.004685  0.036344   20.705532   -0.489270   240.799255  3.549779  1.864270
# 1  0.002049 -0.087893   29.698154   26.771241   515.632716  3.613658  1.863566
# 2  0.006183 -0.036170   -5.255476    5.576694   160.149863  4.846285  1.861704
# 3 -0.009084  0.068295 -130.585004 -107.924717  3505.544029  3.703816  1.861898
# 4  0.017966  0.111452   -6.653483   -4.376791   136.765617  3.452816  1.867071
#
# [5 rows x 27 columns]

# %%
df['hh_PX'] = df['pip_PX'] + df['pim_PX']
df['hh_PY'] = df['pip_PY'] + df['pim_PY']
df['hh_PZ'] = df['pip_PZ'] + df['pim_PZ']
df['KS_PX'] = df['KS_pip_PX'] + df['KS_pim_PX']
df['KS_PY'] = df['KS_pip_PY'] + df['KS_pim_PY']
df['KS_PZ'] = df['KS_pip_PZ'] + df['KS_pim_PZ']
df['pip_E'] = np.sqrt(df['pip_PX']**2 + df['pip_PY']**2 + df['pip_PZ']**2 + 0.13957**2)
df['pim_E'] = np.sqrt(df['pim_PX']**2 + df['pim_PY']**2 + df['pim_PZ']**2 + 0.13957**2)
df['KS_pip_E'] = np.sqrt(df['KS_pip_PX']**2 + df['KS_pip_PY']**2 + df['KS_pip_PZ']**2 + 0.13957**2)
df['KS_pim_E'] = np.sqrt(df['KS_pim_PX']**2 + df['KS_pim_PY']**2 + df['KS_pim_PZ']**2 + 0.13957**2)
df['KS_hh_DOCA'] = doca( df['KS_vtxX'], df['KS_vtxY'], df['KS_vtxZ'], slope(df['KS_PX'], df['KS_PZ']), slope(df['KS_PY'], df['KS_PZ']), 
                         df['D0_vtxX'], df['D0_vtxY'], df['D0_vtxZ'], slope(df['hh_PX'], df['hh_PZ']), slope(df['hh_PY'], df['hh_PZ']) )
df['KS_VERTEX_CHI2'] = np.zeros(len(df))  # Placeholder, need to compute from vertex fit
df['hh_VERTEX_CHI2'] = np.zeros(len(df))  # Placeholder, need to compute from vertex fit
df['D0_DL'] = np.sqrt( (df['D0_vtxX'] - df['Dst_vtxX'])**2 + (df['D0_vtxY'] - df['Dst_vtxY'])**2 + (df['D0_vtxZ'] - df['Dst_vtxZ'])**2 )
df['KS_hh_PT'] = 1000.*( (df['hh_PX']+df['KS_PX'])**2 + (df['hh_PY']+df['KS_PY'])**2)**0.5
df['KS_hh_CTAU'] = ctau( df['D0_DL'], 1864.83, df['KS_hh_PT'] )
df['KS_hh_MASS'] = 1000.*mass( df['hh_PX'] + df['KS_PX'], df['hh_PY'] + df['KS_PY'], df['hh_PZ'] + df['KS_PZ'], df['pip_E'] + df['pim_E'] + df['KS_pip_E'] + df['KS_pim_E'] )
df['KS_PT'] = 1000.*(df['KS_PX']**2 + df['KS_PY']**2)**0.5
df['KS_ETA'] = pseudorapidity( df['KS_PX'], df['KS_PY'], df['KS_PZ'] )
df['KS_Z'] = df['KS_vtxZ']
df['hh_Z'] = df['D0_vtxZ']
df['KS_MASS'] = 1000.*mass( df['KS_PX'], df['KS_PY'], df['KS_PZ'], df['KS_pip_E'] + df['KS_pim_E'] )
df['KS_h1_PT'] = 1000.*(df['KS_pip_PX']**2 + df['KS_pip_PY']**2)**0.5
df['KS_h2_PT'] = 1000.*(df['KS_pim_PX']**2 + df['KS_pim_PY']**2)**0.5
df['KS_h1_P'] = 1000.*(df['KS_pip_PX']**2 + df['KS_pip_PY']**2 + df['KS_pip_PZ']**2)**0.5
df['KS_h2_P'] = 1000.*(df['KS_pim_PX']**2 + df['KS_pim_PY']**2 + df['KS_pim_PZ']**2)**0.5
df['KS_h1_IP'] = df['KS_pip_IP']
df['KS_h2_IP'] = df['KS_pim_IP']
df['hh_PT'] = 1000.*( (df['pip_PX']+df['pim_PX'])**2 + (df['pip_PY']+df['pim_PY'])**2)**0.5
df['hh_ETA'] = pseudorapidity( df['pip_PX']+df['pim_PX'], df['pip_PY']+df['pim_PY'], df['pip_PZ']+df['pim_PZ'] )
df['hh_DOCA'] = doca( df['D0_vtxX'], df['D0_vtxY'], df['D0_vtxZ'], slope(df['pip_PX'], df['pip_PZ']), slope(df['pip_PY'], df['pip_PZ']), 
                      df['D0_vtxX'], df['D0_vtxY'], df['D0_vtxZ'], slope(df['pim_PX'], df['pim_PZ']), slope(df['pim_PY'], df['pim_PZ']) )
df['h1_PT'] = 1000.*(df['pip_PX']**2 + df['pip_PY']**2)**0.5
df['h2_PT'] = 1000.*(df['pim_PX']**2 + df['pim_PY']**2)**0.5
df['h1_P'] = 1000.*(df['pip_PX']**2 + df['pip_PY']**2 + df['pip_PZ']**2)**0.5
df['h2_P'] = 1000.*(df['pim_PX']**2 + df['pim_PY']**2 + df['pim_PZ']**2)**0.5
df['h1_IP'] = df['pip_IP']
df['h2_IP'] = df['pim_IP']
df['hh_Z'] = df['D0_vtxZ']

# %%
from d02kspipi_asymmetry.selections import hlt1_d2kspipi
df['hlt1_d2kspipi'] = hlt1_d2kspipi(df)
df['hlt1_d2kspipi'].value_counts()
df_hlt1d2kspipi = df[df['hlt1_d2kspipi']]

# %%
fig, ax = plot_removed(df['KS_hh_CTAU'].to_numpy()/0.4101, df['hlt1_d2kspipi'].to_numpy(), name=r'$\tau/\tau_{PDG}$', bins=50, range=(0, 5), log=True)

# %% [markdown]
# ## Compare distributions of the two selected samples

# %%
df_hlt1d2pipi['h1_P'] = 1000.*(df_hlt1d2pipi['pip_PX']**2 + df_hlt1d2pipi['pip_PY']**2 + df_hlt1d2pipi['pip_PZ']**2)**0.5
df_hlt1d2pipi['h2_P'] = 1000.*(df_hlt1d2pipi['pim_PX']**2 + df_hlt1d2pipi['pim_PY']**2 + df_hlt1d2pipi['pim_PZ']**2)**0.5
# ['hh_PT', 'hh_VERTEX_CHI2', 'hh_ETA', 'hh_DOCA', 'h1_PT', 'h2_PT', 'h1_IP', 'h2_IP', 'hh_CTAU', 'hh_MASS', 'hh_Z', 'PV_Z']
fig, ax = plot_hists([df_hlt1d2pipi['hh_PT']/1000., df_hlt1d2kspipi['hh_PT']/1000.], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'$p_T(hh)$', unit='GeV/c', density=True, bins=50, range=(0, 20), log=True)
fig, ax = plot_hists([df_hlt1d2pipi['hh_ETA'], df_hlt1d2kspipi['hh_ETA']], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'$\eta(hh)$', unit='', density=True, bins=50, range=(2, 5), log=True)
# fig, ax = plot_hists([df_hlt1d2pipi['hh_DOCA'], df_hlt1d2kspipi['hh_DOCA']], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
#                      name=r'DOCA(hh)', unit='mm', density=True, bins=50, range=(0, .02), log=True) # IT IS 0 SINCE THEY ORIGINATE FROM THE SAME VERTEX
fig, ax = plot_hists([df_hlt1d2pipi[['h1_PT', 'h2_PT']].min(axis=1)/1000., df_hlt1d2kspipi[['h1_PT', 'h2_PT']].min(axis=1)/1000.], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'min $p_T(h)$', unit='GeV/c', density=True, bins=50, range=(0, 5), log=True)
fig, ax = plot_hists([df_hlt1d2pipi[['h1_P', 'h2_P']].min(axis=1)/1000., df_hlt1d2kspipi[['h1_P', 'h2_P']].min(axis=1)/1000.], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'min $p_T(h)$', unit='GeV/c', density=True, bins=50, range=(0, 150), log=True)
fig, ax = plot_hists([df_hlt1d2pipi[['h1_IP', 'h2_IP']].min(axis=1), df_hlt1d2kspipi[['h1_IP', 'h2_IP']].min(axis=1)], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'min $IP(h)$', unit='mm', density=True, bins=50, range=(0.05, 0.5), log=True)
fig, ax = plot_hists([df_hlt1d2pipi['hh_CTAU']/0.4101, df_hlt1d2kspipi['KS_hh_CTAU']/0.4101], legend=[r'$D^*\to D^0(\to\pi\pi)\pi^+$ (HLT1)', r'$D^*\to D^0(\to K_S^0\pi\pi)\pi^+$ (HLT1)'], 
                     name=r'$\tau/\tau_{D^0}$', unit=None, density=True, bins=50, range=(0.4, 10), log=True)
